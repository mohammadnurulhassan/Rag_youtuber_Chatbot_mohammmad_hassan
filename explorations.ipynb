# %% [markdown]
# ##  Expolration RAG _CHAT_BOT

# %%
import lancedb

db= lancedb.connect(uri="konowledge_base")
db
# Out:
# LanceDBConnection(uri='c:\\Users\\mdnrl\\Documents\\github\\Rag_youtuber_Chatbot_mohammmad_hassan\\konowledge_base')

# %%
db.uri
# Out:
# 'c:\\Users\\mdnrl\\Documents\\github\\Rag_youtuber_Chatbot_mohammmad_hassan\\konowledge_base'

# %%
from pathlib import Path
import os

from backend.constants import DATA_PATH, VECTOR_DATABASE_PATH

print("Project root:", Path.cwd())
print("DATA_PATH:", DATA_PATH)
print("VECTOR_DATABASE_PATH:", VECTOR_DATABASE_PATH)
# Out:
# Project root: c:\Users\mdnrl\Documents\github\Rag_youtuber_Chatbot_mohammmad_hassan
# DATA_PATH: c:\Users\mdnrl\Documents\github\Rag_youtuber_Chatbot_mohammmad_hassan\data
# VECTOR_DATABASE_PATH: c:\Users\mdnrl\Documents\github\Rag_youtuber_Chatbot_mohammmad_hassan\knowledge_base

# %%
md_files = sorted(DATA_PATH.glob("*.md"))

print(f"Found {len(md_files)} markdown files in {DATA_PATH}:\n")
for p in md_files:
    print("-", p.name)
# Out:
# Found 47 markdown files in c:\Users\mdnrl\Documents\github\Rag_youtuber_Chatbot_mohammmad_hassan\data:
#
# - An introduction to the vector database LanceDB.md
# - API trafiklab.md
# - Azure static web app deploy react app.md
# - Chat with your excel data - xlwings lite.md
# - Course structure for Azure two weeks course.md
# - Data platform course structure.md
# - data processing course  structure.md
# - data storytelling.md
# - dbt modeling snowflake.md
# - docker setup windows.md
# - FastAPI and scikit-learn API connect to streamlit frontend.md
# - Fastapi CRUD app.md
# - Hands on regularization.md
# - How does LLM work_.md
# - Logistic regression hands on with scikit learn.md
# - Logistic regression theory.md
# - Modern data stack - deploy dockerized dashboard into Azure web app.md
# - Modern data stack - dockerize your data pipeline.md
# - Modern data stack - using dlt to extract and load api data to snowflake.md
# - Packaging in python.md
# - pandas_read_excel.md
# - postgres sink.md
# - Pydantic fundamentals.md
# - Pydantic with gemini to structure output in a much neater way.md
# - pydanticAI chatbot.md
# - PydanticAI fundamentals - outputting structured pydantic model.md
# - pytest unit testing.md
# - Python fundamentals.md
# - python intro.md
# - Python_oop_1.md
# - Serving PydanticAI Gemini Model with FastAPI Tutorial.md
# - SQL analytics course with DuckDB - course structure.md
# - SQL analytics course with DuckDB - CRUD operations tutorial.md
# - SQL analytics course with DuckDB - dlt to load sakila data from SQLite into DuckDB.md
# - SQL analytics course with DuckDB - joins concepts.md
# - SQL analytics course with DuckDB - joins with sakila database tutorial.md
# - SQL analytics course with DuckDB - pandas and duckdb.md
# - SQL analytics course with DuckDB - Sakila BI dashboard using Evidence.md
# - SQL analytics course with DuckDB - set theory part 2 (using Sakila).md
# - SQL analytics course with DuckDB - setup duckdb.md
# - SQL analytics course with DuckDB - strings concepts.md
# - SQL analytics course with DuckDB - strings tutorial.md
# - SQL analytics course with DuckDB - subquery tutorial.md
# - SQL analytics course with DuckDB - views tutorial.md
# - SQL analytics with DuckDB - introduction.md
# - Terraform setup.md
# - XGBoost hands on tutorial for classification.md

# %%
print("8", p.name)
# Out:
# 8 XGBoost hands on tutorial for classification.md

# %%
print("29", p.name)
# Out:
# 29 XGBoost hands on tutorial for classification.md

# %%
# Cell 3: Preview a specific markdown file

# Pick a file index from the printed list above
idx = 19  # change 0 -> 1,2,3... to see another file

file_path = md_files[idx]
print("Previewing:", file_path.name, "\n", "-" * 50)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

print(text[:1500])  # show first 1500 characters
# Out:
# Previewing: Packaging in python.md
#  --------------------------------------------------
# # Packaging in python
#
# [00:00:00] Hello and welcome to this lecture where we'll go into packaging a Python project. ~~And ~~as you will see, packaging a Python project will make it much simpler with importing because as you might have noticed when you're importing modules from different folders, it might give you troubles in Python.
#
# However, ~~whenever, ~~when you have packaged it, you can. pip install it. And when you have pip installed it as a package it is very intuitive to use the modules that you have created. So we will create a real application here that we'll call the travel planner that will use an API.
#
# And as you will see, this application contains a lot of different modules separated into different directories. And this is ~~a ~~kind of the idea so that you can see when you're growing a larger and larger project you really should package it
#
# we will move on to a visual studio code.
#
# [00:01:00] So in a previous lecture, you have already seen me working with travel API from traffic lab. So I won't go through that. ~~Again, instead you will go in, ~~you can go in there ~~to ~~to look at my previous lecture.
#
# So I'll just create a new terminal. And let's start with creating a virtual environment. So uv venv. So now we have a virtual environment. Let's activate that source. vnv, bin activate. Okay. It has been activated and you can see that from the parentheses, but it's not always sure that the parentheses is there.
#
# ~~It's ~~depends on how your terminal is configure

# %%
# Cell 3: Preview a specific markdown file

# Pick a file index from the printed list above
idx = 9  # change 0 -> 1,2,3... to see another file

file_path = md_files[idx]
print("Previewing:", file_path.name, "\n", "-" * 50)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

print(text[:1000])  # show first 1500 characters
# Out:
# Previewing: docker setup windows.md
#  --------------------------------------------------
# # docker setup windows
#
# [00:00:00] Hello and welcome to this video where I will go into installing a docker on my Windows machine. And for that they will need to install WSL, so Windows subsystem for Linux. And then afterwards we'll install the Docker desktop. And when that's done we'll do a test to, create an image from a docker file and ~~then ~~then from that will spin up a container to see that it works. So moving on to my windows virtual machine now.~~ So ~~here I am in my Windows machine. ~~So ~~let's go into the browser. Microsoft Edge, for example. I haven't installed another browser, so I will use this one. ~~So here let's down go in. So ~~you go into this web page, which is also in my GitHub repo, the documentation. ~~So ~~here you find ~~desktop ~~docker desktop for Windows, and I'll pick this one.
#
# And you download it. Yeah, ~~this goes quite quickly, but ~~I have downloaded this before. So I have it here the Docker [00:01:00] desktop installer. So just double click this on

# %%
file_path = md_files[idx]
print("Previewing:", file_path.name, "\n", "-" * 80)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

print(text[:2000])
# Out:
# Previewing: docker setup windows.md
#  --------------------------------------------------------------------------------
# # docker setup windows
#
# [00:00:00] Hello and welcome to this video where I will go into installing a docker on my Windows machine. And for that they will need to install WSL, so Windows subsystem for Linux. And then afterwards we'll install the Docker desktop. And when that's done we'll do a test to, create an image from a docker file and ~~then ~~then from that will spin up a container to see that it works. So moving on to my windows virtual machine now.~~ So ~~here I am in my Windows machine. ~~So ~~let's go into the browser. Microsoft Edge, for example. I haven't installed another browser, so I will use this one. ~~So here let's down go in. So ~~you go into this web page, which is also in my GitHub repo, the documentation. ~~So ~~here you find ~~desktop ~~docker desktop for Windows, and I'll pick this one.
#
# And you download it. Yeah, ~~this goes quite quickly, but ~~I have downloaded this before. So I have it here the Docker [00:01:00] desktop installer. So just double click this one.
#
# ~~So ~~when installing this, it will take some time. However, it won't work for you immediately ~~when you install it. ~~So it says ~~like this, ~~use WSL2 instead of Hyper V recommended and add shortcut to desktop. So I'll just install this one.
#
# ~~So ~~now my installation has finished. ~~So ~~it says ~~here~~ close and restart. So ~~I will, ~~I'll do that. ~~So close and restart. ~~
#
# Okay. Now I've restarted my computer and ~~we'll see that ~~you see that there's ~~a ~~ Docker desktop here. So I'll double click this one
#
# and you can see that. Okay. Just accept this one, read it through and accept it.
#
# And here finish setting up Docker use recommended settings requires administrator password use advanced settings. I'll use recommended. So finish.
#
# Okay. Welcome to Docker. Just skip this one. And yeah, you can skip this one as well.[00:02:00]
#
# So Docker engine stopped. This is interesting. So let's see what it says here. ~~Starting dock, ~~starting the docker engine.
#
# I think it w

# %%
# Cell 4: Connect to LanceDB and inspect the articles table

import lancedb

db = lancedb.connect(VECTOR_DATABASE_PATH)

print("Tables:", db.table_names())
# Out:
# Tables: []

# %%
# Cell 5: View articles as pandas DataFrame

import pandas as pd

df = articles.to_pandas()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       1 # Cell 5: View articles as pandas DataFrame
#       3 import pandas as pd
# ----> 5 df = articles.to_pandas()
#       6 df.head()
#
# NameError: name 'articles' is not defined
